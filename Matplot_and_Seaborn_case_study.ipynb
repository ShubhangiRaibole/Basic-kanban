# %% [markdown]
# <a href="https://colab.research.google.com/github/ShubhangiRaibole/Basic-kanban/blob/master/Matplot_and_Seaborn_case_study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
df=pd.read_csv('heart.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import statistics as stats
import math 
import warnings
warnings.filterwarnings ('ignore')
# %matplotlib inline

# %% [markdown]
# **1.3 How to see the size of your data? **

# %%
df.size
# Out:
# 4242

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0   63    1   3       145   233    1  ...      0      2.3      0   0     1       1
# 1   37    1   2       130   250    0  ...      0      3.5      0   0     2       1
# 2   41    0   1       130   204    0  ...      0      1.4      2   0     2       1
# 3   56    1   1       120   236    0  ...      0      0.8      2   0     2       1
# 4   57    0   0       120   354    0  ...      1      0.6      2   0     2       1
#
# [5 rows x 14 columns]

# %% [markdown]
# **1.4 How to view the statistical characteristics of the data?**

# %%
df.mean
# Out:
# <bound method DataFrame.mean of      age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0     63    1   3       145   233    1  ...      0      2.3      0   0     1       1
# 1     37    1   2       130   250    0  ...      0      3.5      0   0     2       1
# 2     41    0   1       130   204    0  ...      0      1.4      2   0     2       1
# 3     56    1   1       120   236    0  ...      0      0.8      2   0     2       1
# 4     57    0   0       120   354    0  ...      1      0.6      2   0     2       1
# ..   ...  ...  ..       ...   ...  ...  ...    ...      ...    ...  ..   ...     ...
# 298   57    0   0       140   241    0  ...      1      0.2      1   0     3       0
# 299   45    1   3       110   264    0  ...      0      1.2      1   0     3       0
# 300   68    1   0       144   193    1  ...      0      3.4      1   2     3       0
# 301   57    1   0       130   131    0  ...      1      1.2      1   1     3       0
# ...

# %%
df.median
# Out:
# <bound method DataFrame.median of      age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0     63    1   3       145   233    1  ...      0      2.3      0   0     1       1
# 1     37    1   2       130   250    0  ...      0      3.5      0   0     2       1
# 2     41    0   1       130   204    0  ...      0      1.4      2   0     2       1
# 3     56    1   1       120   236    0  ...      0      0.8      2   0     2       1
# 4     57    0   0       120   354    0  ...      1      0.6      2   0     2       1
# ..   ...  ...  ..       ...   ...  ...  ...    ...      ...    ...  ..   ...     ...
# 298   57    0   0       140   241    0  ...      1      0.2      1   0     3       0
# 299   45    1   3       110   264    0  ...      0      1.2      1   0     3       0
# 300   68    1   0       144   193    1  ...      0      3.4      1   2     3       0
# 301   57    1   0       130   131    0  ...      1      1.2      1   1     3       0
# ...

# %%
df.mode
# Out:
# <bound method DataFrame.mode of      age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0     63    1   3       145   233    1  ...      0      2.3      0   0     1       1
# 1     37    1   2       130   250    0  ...      0      3.5      0   0     2       1
# 2     41    0   1       130   204    0  ...      0      1.4      2   0     2       1
# 3     56    1   1       120   236    0  ...      0      0.8      2   0     2       1
# 4     57    0   0       120   354    0  ...      1      0.6      2   0     2       1
# ..   ...  ...  ..       ...   ...  ...  ...    ...      ...    ...  ..   ...     ...
# 298   57    0   0       140   241    0  ...      1      0.2      1   0     3       0
# 299   45    1   3       110   264    0  ...      0      1.2      1   0     3       0
# 300   68    1   0       144   193    1  ...      0      3.4      1   2     3       0
# 301   57    1   0       130   131    0  ...      1      1.2      1   1     3       0
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0     63    1   3       145   233    1  ...      0      2.3      0   0     1       1
# 1     37    1   2       130   250    0  ...      0      3.5      0   0     2       1
# 2     41    0   1       130   204    0  ...      0      1.4      2   0     2       1
# 3     56    1   1       120   236    0  ...      0      0.8      2   0     2       1
# 4     57    0   0       120   354    0  ...      1      0.6      2   0     2       1
# ..   ...  ...  ..       ...   ...  ...  ...    ...      ...    ...  ..   ...     ...
# 298   57    0   0       140   241    0  ...      1      0.2      1   0     3       0
# 299   45    1   3       110   264    0  ...      0      1.2      1   0     3       0
# 300   68    1   0       144   193    1  ...      0      3.4      1   2     3       0
# 301   57    1   0       130   131    0  ...      1      1.2      1   1     3       0
# ...

# %%
df.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 298   57    0   0       140   241    0  ...      1      0.2      1   0     3       0
# 299   45    1   3       110   264    0  ...      0      1.2      1   0     3       0
# 300   68    1   0       144   193    1  ...      0      3.4      1   2     3       0
# 301   57    1   0       130   131    0  ...      1      1.2      1   1     3       0
# 302   57    0   1       130   236    0  ...      0      0.0      1   1     2       0
#
# [5 rows x 14 columns]

# %% [markdown]
# **1.5 a How to see just one column?**

# %%
df['age']
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %% [markdown]
# **b How to check the column names?**

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# **Change the column names?**

# %%
df.rename(columns = {'age':'age_1','sex':'gender'} ,inplace=True)

# %%
df.columns
# Out:
# Index(['age_1', 'gender', 'cp', 'trestbps', 'chol', 'fbs', 'restecg',
#        'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.rename(columns = {'age_1':'age','gender':'sex'} ,inplace=True)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# **1.5 c Find the Numerical Features,Categorical Features, Alphanumeric Features?**

# %% [markdown]
# **Quantitative**

# %% [markdown]
# **a) Create kdeplot for showing age**

# %%
 ax = sns .kdeplot(df.age,kernel='cos',bw='silverman')

# %%
ax = sns.kdeplot(df.age,shade= True)

# %% [markdown]
# **1.6 a) Create histogram for showing cholestrol with Number of bins 5**

# %%
df['chol'].describe()
# Out:
# count    303.000000
# mean     246.264026
# std       51.830751
# min      126.000000
# 25%      211.000000
# 50%      240.000000
# 75%      274.500000
# max      564.000000
# Name: chol, dtype: float64

# %%
plt.hist (df['chol'],bins=5)
plt.show()

# %% [markdown]
# **1.6 c) Create Boxplot for showing trestbps and comment what the dark spot indicate**

# %%
sns.catplot(x='trestbps',hue= "trestbps",data=df,kind='box')

# %% [markdown]
# block spot show as a quack observation what is showing in a box plot

# %% [markdown]
# **Categorical vs. Quantitativet**

# %% [markdown]
# **1.8a) Create bar plot for showing Gender and target. And your Observation:**

# %%
#draw a bar plot of target by sex


#print percentages of females vs. males Heart Disease

# %%
sns.barplot(x='target',y='sex',hue='age',data=df)

# %%
df.plot.bar('sex')

# %% [markdown]
# Observation:**

# %% [markdown]
# **1.8b) Create Bar plot for checking the both target vs Sex**

# %%
#create a subplot

# %%
plt.figure()
x= np.linspace(1,2,10)
plt.subplot(1,1,1)
plt.plot(x,'ks')
plt.title('chest_pain_type ')
# Out:
# Text(0.5, 1.0, 'chest_pain_type ')

# %%
# create bar plot using groupby

# %%
df.groupby('target').plot.barh()
# Out:
# target
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
df.groupby('sex').plot.barh()
# Out:
# sex
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
# create count plot

# %%
x=['target']
ax=sns.countplot(x="target",data=df,color="green")

# %%
x=['sex']
ax=sns.countplot(x="sex",data=df,color="pink")

# %%
# create bar plot using groupby

# %%
df.groupby('cp').plot.barh()
# Out:
# cp
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# 2    AxesSubplot(0.125,0.125;0.775x0.755)
# 3    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
df.groupby('cp').plot

# %%
# create count plot

# %%
ax=sns.countplot(x="cp",data=df,color="red")

# %%
# create subplot plot

# %%
plt.figure()
x= np.linspace(1,5,10)
plt.subplot(1,1,1)
plt.plot(x,'ro')
plt.title('chest_pain_type ')
# Out:
# Text(0.5, 1.0, 'chest_pain_type ')

# %% [markdown]
# **1.8d) Create Bar plot for checking the both Number Of people having chest_pain_type vs chest_pain_type:Heart Disease or Not.**

# %%
# create violinplot plot using groupby

# %%
sns.violinplot(x="fbs",y="age",data=df)

# %%
sns.violinplot(x="fbs",y="target",data=df,palette='Dark2')

# %% [markdown]
# **1.8 d)create a box plot for Sex & Age**

# %%
# create boxplot

# %%
sns.catplot(x="age",y="sex",data =df,kind='box' )

# %% [markdown]
# ***1.9 Categorical vs. Categorical ***

# %% [markdown]
# **1.9 a) Create a Stacked bar chart for showing target & Sex**

# %%
from textwrap import wrap 
import numpy as np

# %%
from textwrap import wrap 
import numpy as np

# %%
plt.figure(figsize=(10,7))

graphtarget = plt.bar(x=index, height=target ,width=0.35)
graphsex = plt.bar(x=index, height=sex,width=0.35,bottom = sex)

plt.xlabel('target')
plt.ylabel('heart')

plt.show( )

# %%
df.plot(kind.'target', stocked=True)
df.plot(kind.'sex',stocked=True)
plt

# %%
#create crosstab

# %%
pd.crosstab(df.sex,df.target,margins=True)
# Out:
# target    0    1  All
# sex
# 0        24   72   96
# 1       114   93  207
# All     138  165  303

# %%
pd.crosstab(df.target,df.sex,margins=True)
# Out:
# sex      0    1  All
# target
# 0       24  114  138
# 1       72   93  165
# All     96  207  303

# %% [markdown]
# **1.10 Quantitative vs. Quantitative**

# %% [markdown]
# **1.10 a) Create a scatter plot for showing age & st_depression**

# %%
df.plot.scatter(x='age',y='oldpeak')

# %%
sns.set_style('white')
sns.set_style('ticks')

sns.regplot(x='age', y='oldpeak',color='g',data=df)

# %%
sns.lmplot(x='age',y='oldpeak',hue='sex',data=df)

# %% [markdown]
# **Overall Observation **
