# %% [markdown]
# <a href="https://colab.research.google.com/github/ShubhangiRaibole/Basic-kanban/blob/master/Unsupervised_Learning__K_mean_Clustering)s.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  # Import Useful Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#Load Dataset
wine=pd.read_csv("winequality-red.csv")

# %%
#check head 
wine.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70         0.00  ...       0.56      9.4        5
# 1            7.8              0.88         0.00  ...       0.68      9.8        5
# 2            7.8              0.76         0.04  ...       0.65      9.8        5
# 3           11.2              0.28         0.56  ...       0.58      9.8        6
# 4            7.4              0.70         0.00  ...       0.56      9.4        5
#
# [5 rows x 12 columns]

# %%
#Check unique Quality
wine.quality.unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
# Drop Quality Feature From Dataset
wine.drop(columns=['quality'])
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  ...    pH  sulphates  alcohol
# 0               7.4             0.700         0.00  ...  3.51       0.56      9.4
# 1               7.8             0.880         0.00  ...  3.20       0.68      9.8
# 2               7.8             0.760         0.04  ...  3.26       0.65      9.8
# 3              11.2             0.280         0.56  ...  3.16       0.58      9.8
# 4               7.4             0.700         0.00  ...  3.51       0.56      9.4
# ...             ...               ...          ...  ...   ...        ...      ...
# 1594            6.2             0.600         0.08  ...  3.45       0.58     10.5
# 1595            5.9             0.550         0.10  ...  3.52       0.76     11.2
# 1596            6.3             0.510         0.13  ...  3.42       0.75     11.0
# 1597            5.9             0.645         0.12  ...  3.57       0.71     10.2
# ...

# %%
#check pairplot
import seaborn as sns
sns.set(style="ticks",color_codes=True)
g = sns.pairplot(wine,hue="quality")

# %%
# Scale the Dataset

# Initialise the Scaler 
scaler = StandardScaler() 
  
# To scale data 
scaler.fit(wine)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %% [markdown]
# ##Perform Kmean Clustering - (15 marks)**

# %%
# Let us check optimal number of clusters-

# expect 3 to four clusters from the pair panel visual inspection hence restricting from 2 to 6


# capture the cluster lables
  

# capture the centroids
 

# capture the intertia
 

# combine the cluster_range and cluster_errors into a dataframe by combining them

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(wine)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
labels = kmeans.predict(wine)

labels
# Out:
# array([1, 2, 2, ..., 2, 2, 2], dtype=int32)

# %%
centroids=kmeans.cluster_centers_
centroids=pd.DataFrame(centroids, columns=['','fixed_acidity'	,'volatile_acidity'	,'citric_acid'	,'residual_sugar'	,'chlorides'	,'free_sulfur_dioxide	','total_sulfur_dioxide'	,'density',	'pH'	,'sulphates','alcohol'])
centroids
# Out:
#              fixed_acidity  volatile_acidity  ...        pH  sulphates   alcohol
# 0  7.887552       0.572365          0.275643  ...  0.652033  10.008921  5.307054
# 1  8.469828       0.519520          0.268608  ...  0.647217  10.576929  5.738916
# 2  8.286996       0.520504          0.272436  ...  0.677106  10.376801  5.628205
#
# [3 rows x 12 columns]

# %%
kmeans= kmeans(n_clusters=3)
kmeans=fit(df)
kmeans.inertia_
print()

# %%
# Normalizing over the standard deviation
wine_dropped = wine.drop('quality', axis=1)
X =df_dropped.values[:, 1:]
Clus_dataset = StandardScaler().fit_transform(X)

# %%
# Elbow plot

# %%
# Basically, number of clusters = the x-axis value of the point that is the corner of the "elbow"(the plot looks often looks like an elbow)
wcss = []
for i in range(1,12):
    kmeans = KMeans(n_clusters=i,init='k-means++',max_iter=300, n_init=12, random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
f3, ax = plt.subplots(figsize=(8, 6))
plt.plot(range(1,12),wcss)
plt.title('Elbow plot')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# ## Take Appropriate Cluster and Build a Kmean Cluster

# %%
# Using scikit-learn to perform K-Means clustering
from sklearn.cluster import KMeans
    
# Specify the number of clusters (3) and fit the data X
kmeans = KMeans(n_clusters=3, random_state=0).fit(X)

# %%
# Get the cluster centroids
print(kmeans.cluster_centers_)
    
# Get the cluster labels
print(kmeans.labels_)
# Out:
# [[5.20503663e-01 2.72435897e-01 2.49706960e+00 9.13095238e-02
#   2.15705128e+01 5.48882784e+01 9.96855769e-01 3.32020147e+00
#   6.77106227e-01 1.03768010e+01]
#  [5.72365145e-01 2.75643154e-01 3.23236515e+00 8.83983402e-02
#   2.61514523e+01 1.08506224e+02 9.96934730e-01 3.28962656e+00
#   6.52033195e-01 1.00089212e+01]
#  [5.19519704e-01 2.68608374e-01 2.36102217e+00 8.46059113e-02
#   8.99507389e+00 2.23928571e+01 9.96617512e-01 3.31137931e+00
#   6.47216749e-01 1.05769294e+01]]
# [2 0 0 ... 0 0 0]

# %%
#Plotting the cluster centers and the data points 
plt.scatter(X[:, 0], X[:, -1])
    
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c='red', marker='x')
    
plt.title('Data points and cluster centroids')
plt.show()

# %%
wine['cluster'] = labels
wine.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  ...  alcohol  quality  cluster
# 0            7.4              0.70         0.00  ...      9.4        5        1
# 1            7.8              0.88         0.00  ...      9.8        5        2
# 2            7.8              0.76         0.04  ...      9.8        5        2
# 3           11.2              0.28         0.56  ...      9.8        6        2
# 4            7.4              0.70         0.00  ...      9.4        5        1
#
# [5 rows x 13 columns]

# %% [markdown]
# #hint

# %%
wine_kmeans label = pd.merge(wine,kmeans label)
wine_kmeans labels.columns

# %% [markdown]
# #Use silhouette_Coefficient to Find best No of Cluster -(5 Marks)

# %%
# A list holds the silhouette coefficients for each k
silhouette_coefficients = []
# Notice you start at 2 clusters for silhouette coefficient
for k in range(2, 12):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(df)
    score = silhouette_score(df, kmeans.labels_)
    silhouette_coefficients.append(score)

# %%
plt.plot(range(2, 12), silhouette_coefficients)
plt.xticks(range(2, 12))
plt.xlabel("Number of Clusters") 
plt.ylabel("Silhouette Coefficient")
plt.show()

# %%
# Calculate silhouette_score
from sklearn.metrics import silhouette_score

print(silhouette_score(X, kmeans.labels_))
# Out:
# 0.4021636978648799

# %%
#final Boxplot
plt.boxplot(wine.quality)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fc9867fdc50>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fc986807748>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc98680e2b0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc986807eb8>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fc9867fdf98>,
#   <matplotlib.lines.Line2D at 0x7fc986807390>]}

# %% [markdown]
# #**Build a Dendogram -(5 marks)**

# %%
from scipy.cluster.hierarchy import dendrogram,linkage
import numpy as np

# %%
np.set_printoptions(precision=5,suppress=True)

# %%
Z = linkage(df,'ward')
from scipy.cluster.hierarchy import cophenet
from scipy.spatial.distance import pdist
c,coph_dists=cophenet(Z,pdist(df))
c
# Out:
# 0.7526354879716999

# %%
plt.figure(figsize=(25,10))
plt.title('clustering dendrogram')
plt.xlabel('sample_index')
plt.ylabel('distance')
dendrogram(
    Z,
    leaf_rotation=90.,
    leaf_font_size=8.,
)
plt.show()
