# %% [markdown]
# <a href="https://colab.research.google.com/github/ShubhangiRaibole/Basic-kanban/blob/master/flower%20analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import sys, os, multiprocessing, csv
from urllib import request, error
from PIL import Image
from io import BytesIO

# %%
import cv2

# %%
 img = Image.open("images.jpg")

# %%
img.size
# Out:
# (242, 208)

# %%
img = cv2.imread('images.jpg')

# %%
# Python program to read  
# image using matplotlib 
  
# importing matplotlib modules 
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt 
   
 
# Output Images 
plt.imshow(img)

# %%
# prints format of image 
print(img)
# Out:
# [[[ 98 156 115]
#   [ 96 154 113]
#   [ 94 152 111]
#   ...
#   [ 85 148 109]
#   [ 93 141 105]
#   [ 93 141 105]]
#
#  [[ 95 153 112]
#   [ 93 151 110]
#   [ 89 149 108]
#   ...
#   [ 85 148 109]
#   [ 94 142 106]
#   [ 94 142 106]]
#
#  [[ 90 148 107]
#   [ 86 146 105]
#   [ 85 145 104]
#   ...
#   [ 85 148 109]
#   [ 93 144 107]
#   [ 93 144 107]]
#
#  ...
#
#  [[ 66 110  79]
#   [ 62 109  77]
#   [ 58 105  73]
#   ...
#   [ 25 129  76]
#   [ 33 129  82]
#   [ 33 129  82]]
#
#  [[ 54 109  76]
#   [ 53 108  75]
#   [ 50 104  74]
#   ...
#   [ 37 132  81]
#   [ 43 133  87]
#   [ 43 133  87]]
#
#  [[ 47 108  74]
#   [ 46 106  75]
#   [ 45 103  74]
#   ...
#   [ 48 135  85]
#   [ 49 137  91]
#   [ 49 137  91]]]

# %%
# !pip install opencv_python

# %%
help (cv2.kmeans)
# Out:
# Help on built-in function kmeans:
#
# kmeans(...)
#     kmeans(data, K, bestLabels, criteria, attempts, flags[, centers]) -> retval, bestLabels, centers
#     .   @brief Finds centers of clusters and groups input samples around the clusters.
#     .
#     .   The function kmeans implements a k-means algorithm that finds the centers of cluster_count clusters
#     .   and groups the input samples around the clusters. As an output, \f$\texttt{bestLabels}_i\f$ contains a
#     .   0-based cluster index for the sample stored in the \f$i^{th}\f$ row of the samples matrix.
#     .
#     .   @note
#     .   -   (Python) An example on K-means clustering can be found at
#     .       opencv_source_code/samples/python/kmeans.py
#     .   @param data Data for clustering. An array of N-Dimensional points with float coordinates is needed.
#     .   Examples of this array can be:
#     .   -   Mat points(count, 2, CV_32F);
#     .   -   Mat points(count, 1, CV_32FC2);
# ...

# %%
print(img.shape)
# Out:
# (208, 242, 3)

# %%
Vimg = img.reshape(-1,3)

# %%
Vimg.shape
# Out:
# (50336, 3)

# %%
Vimg=np.float32 (Vimg)
Vimg.dtype
# Out:
# dtype('float32')

# %%
Criteris = (cv2.TERM_CRITERIA_EPS+cv2.TERM_CRITERIA_MAX_ITER,10,10)
